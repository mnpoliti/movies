# %% [markdown]
# ### import pandas

# %%
import pandas as pd

# %% [markdown]
# #### 1. import dataset imdb.csv

# %%
df1 = pd.read_csv("imdb.csv")

# %%
df1.head()
# Out:
#                           Name  Date Rate    Votes  \
# 0               No Time to Die  2021  7.6  107,163
# 1                   The Guilty  2021  6.3   64,375
# 2    The Many Saints of Newark  2021  6.4   27,145
# 3  Venom: Let There Be Carnage  2021  6.4   30,443
# 4                         Dune  2021  8.3   84,636
#
#                          Genre Duration  Type Certificate Episodes    Nudity  \
# 0  Action, Adventure, Thriller      163  Film       PG-13        -      Mild
# 1       Crime, Drama, Thriller       90  Film           R        -      None
# 2                 Crime, Drama      120  Film           R        -  Moderate
# 3    Action, Adventure, Sci-Fi       97  Film       PG-13        -      None
# 4     Action, Adventure, Drama      155  Film       PG-13        -      None
#
#    Violence Profanity   Alcohol Frightening
# 0  Moderate      Mild      Mild    Moderate
# 1      None    Severe      None    Moderate
# 2    Severe    Severe  Moderate    Moderate
# ...

# %% [markdown]
# ##### 1.1. Rename the columns

# %%
df1.rename(columns = {'Date':'Year', 'Rate':'Rating',
                              'Genre':'Genre1','Duration':'Runtime'}, inplace = True)

# %%
df1
# Out:
#                                         Name  Year Rating    Votes  \
# 0                             No Time to Die  2021    7.6  107,163
# 1                                 The Guilty  2021    6.3   64,375
# 2                  The Many Saints of Newark  2021    6.4   27,145
# 3                Venom: Let There Be Carnage  2021    6.4   30,443
# 4                                       Dune  2021    8.3   84,636
# ...                                      ...   ...    ...      ...
# 6173  The Human Centipede II (Full Sequence)  2011    3.8   37,492
# 6174                        Double Indemnity  1944    8.3  150,448
# 6175      Before the Devil Knows You're Dead  2007    7.3  100,668
# 6176                              Queen Bees  2021      6      887
# 6177                              Death Race  2008    6.3  203,578
#
#                            Genre1 Runtime  Type Certificate Episodes  \
# 0     Action, Adventure, Thriller     163  Film       PG-13        -
# ...

# %% [markdown]
# #### 2. import dataset IMDB_movie_reviews_details.csv

# %%
df2 = pd.read_csv("IMDB_movie_reviews_details.csv")

# %%
df2.head()
# Out:
#    Unnamed: 0                      name  year  runtime                 genre  \
# 0           0  The Shawshank Redemption  1994      142                 Drama
# 1           1             The Godfather  1972      175          Crime, Drama
# 2           2           Soorarai Pottru  2020      153                 Drama
# 3           3           The Dark Knight  2008      152  Action, Crime, Drama
# 4           4    The Godfather: Part II  1974      202          Crime, Drama
#
#    rating  metascore                                           timeline  \
# 0     9.3       80.0  Two imprisoned men bond over a number of years...
# 1     9.2      100.0  An organized crime dynasty's aging patriarch t...
# 2     9.1        NaN  Nedumaaran Rajangam "Maara" sets out to make t...
# 3     9.0       84.0  When the menace known as the Joker wreaks havo...
# 4     9.0       90.0  The early life and career of Vito Corleone in ...
#
#        votes     gross
# 0  2,394,059   $28.34M
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'name', 'year', 'runtime', 'genre', 'rating', 'metascore',
#        'timeline', 'votes', 'gross'],
#       dtype='object')

# %% [markdown]
# ##### 2.1. Rename the columns

# %%
df2.rename(columns = {'name':'Name','year':'Year', 'rating':'Rating',
                      'genre':'Genre2','runtime':'Runtime',
                      'metascore':'Metascore','timeline':'Description1',
           'votes':'Votes', 'gross':'Gross'}, inplace = True)

# %%
del df2["Unnamed: 0"]

# %%
df2
# Out:
#                          Name  Year  Runtime                  Genre2  Rating  \
# 0    The Shawshank Redemption  1994      142                   Drama     9.3
# 1               The Godfather  1972      175            Crime, Drama     9.2
# 2             Soorarai Pottru  2020      153                   Drama     9.1
# 3             The Dark Knight  2008      152    Action, Crime, Drama     9.0
# 4      The Godfather: Part II  1974      202            Crime, Drama     9.0
# ..                        ...   ...      ...                     ...     ...
# 995    Breakfast at Tiffany's  1961      115  Comedy, Drama, Romance     7.6
# 996                     Giant  1956      201          Drama, Western     7.6
# 997                     Shane  1953      118          Drama, Western     7.6
# 998     From Here to Eternity  1953      118     Drama, Romance, War     7.6
# 999                  Lifeboat  1944       97              Drama, War     7.6
#
# ...

# %% [markdown]
# ##### 2.2. create the first merged dataset ( result1)

# %%
result1 = pd.merge(df1,
                 df2,
                 on='Name')

# %%
result1.head(2)
# Out:
#             Name  Year_x Rating_x  Votes_x                       Genre1  \
# 0  Casino Royale    2006        8  613,873  Action, Adventure, Thriller
# 1  Casino Royale    1967      5.1   28,917                       Comedy
#
#   Runtime_x  Type Certificate Episodes Nudity  ... Alcohol Frightening Year_y  \
# 0       144  Film       PG-13        -   Mild  ...    Mild    Moderate   2006
# 1       131  Film    Approved        -   Mild  ...    Mild        None   2006
#
#   Runtime_y                       Genre2  Rating_y Metascore  \
# 0       144  Action, Adventure, Thriller       8.0      80.0
# 1       144  Action, Adventure, Thriller       8.0      80.0
#
#                                         Description1  Votes_y     Gross
# 0  After earning 00 status and a licence to kill,...  589,686  $167.45M
# 1  After earning 00 status and a licence to kill,...  589,686  $167.45M
#
# [2 rows x 22 columns]

# %%
print(result1)
# Out:
#                           Name  Year_x Rating_x  Votes_x  \
# 0                Casino Royale    2006        8  613,873
# 1                Casino Royale    1967      5.1   28,917
# 2                      Skyfall    2012      7.8  658,977
# 3    What We Do in the Shadows    2021      8.5   50,078
# 4    What We Do in the Shadows    2014      7.7  169,214
# ..                         ...     ...      ...      ...
# 637        Anatomy of a Murder    1959        8   63,564
# 638                      Mommy    2014      8.1   54,020
# 639                      Mommy    2014      8.1   54,020
# 640           Double Indemnity    1944      8.3  150,448
# 641           Double Indemnity    1944      8.3  150,448
#
#                           Genre1 Runtime_x    Type Certificate Episodes  \
# 0    Action, Adventure, Thriller       144    Film       PG-13        -
# 1                         Comedy       131    Film    Approved        -
# ...

# %%
result1.columns
# Out:
# Index(['Name', 'Year_x', 'Rating_x', 'Votes_x', 'Genre1', 'Runtime_x', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Year_y', 'Runtime_y', 'Genre2', 'Rating_y', 'Metascore',
#        'Description1', 'Votes_y', 'Gross'],
#       dtype='object')

# %%
result1 = result1.drop(["Year_y","Runtime_y","Rating_y","Votes_y"], axis=1)
result1.columns
# Out:
# Index(['Name', 'Year_x', 'Rating_x', 'Votes_x', 'Genre1', 'Runtime_x', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre2', 'Metascore', 'Description1', 'Gross'],
#       dtype='object')

# %%
result1.rename(columns = {'Year_x':'Year', 'Rating_x':'Rating',
                              'Votes_x':'Votes','Runtime_x':'Runtime'}, inplace = True)
result1.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre2', 'Metascore', 'Description1', 'Gross'],
#       dtype='object')

# %%
#df1.dtypes

# %%
#df2.dtypes

# %%
#df2 = df2.convert_objects(convert_numeric=True)
#df2.dtypes

# %%
#df2['Year'] = df2.Year.astype(float)

# %%
#trial = pd.merge(df1, df2,  how='left', left_on=['Name','Year'], right_on = ['Name','Year'])

# %% [markdown]
# #### 3. import the dataset IMDB-Movie-Data.csv

# %%
df3= pd.read_csv("IMDB-Movie-Data.csv")
df3.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# ##### 3.1. Rename the columns

# %%
del df3["Rank"]

# %%
df3.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df3.rename(columns = {'Title':'Name','Description':'Description2',
                      'Genre':'Genre3','Runtime (Minutes)':'Runtime',
                      'metascore':'Metascore', 'Revenue (Millions)':'Gross'}, inplace = True)

# %%
df3
# Out:
#                         Name                    Genre3  \
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1                 Prometheus  Adventure,Mystery,Sci-Fi
# 2                      Split           Horror,Thriller
# 3                       Sing   Animation,Comedy,Family
# 4              Suicide Squad  Action,Adventure,Fantasy
# ..                       ...                       ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery
# 996          Hostel: Part II                    Horror
# 997   Step Up 2: The Streets       Drama,Music,Romance
# 998             Search Party          Adventure,Comedy
# 999               Nine Lives     Comedy,Family,Fantasy
#
#                                           Description2              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
###split the genre3 column

# %% [markdown]
# ##### 3.2. create the second merged dataset ( result2 )

# %%
result2 = pd.merge(df1,
                 df3,
                 on='Name')
print(result2)
# Out:
#                           Name  Year_x Rating_x  Votes_x  \
# 0                      Spectre    2015      6.8  407,514
# 1                Casino Royale    2006        8  613,873
# 2                Casino Royale    1967      5.1   28,917
# 3                      Skyfall    2012      7.8  658,977
# 4    What We Do in the Shadows    2021      8.5   50,078
# ..                         ...     ...      ...      ...
# 886                      Mommy    2014      8.1   54,020
# 887                       Elle    2016      7.1   64,036
# 888                       Elle    2016      7.1   64,036
# 889                 Death Race    2008      6.3  203,578
# 890                 Death Race    2008      6.3  203,578
#
#                           Genre1 Runtime_x    Type Certificate Episodes  \
# 0    Action, Adventure, Thriller       148    Film       PG-13        -
# 1    Action, Adventure, Thriller       144    Film       PG-13        -
# ...

# %%
result2.columns
# Out:
# Index(['Name', 'Year_x', 'Rating_x', 'Votes_x', 'Genre1', 'Runtime_x', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre3', 'Description2', 'Director', 'Actors', 'Year_y',
#        'Runtime_y', 'Rating_y', 'Votes_y', 'Gross', 'Metascore'],
#       dtype='object')

# %%
result2 = result2.drop(["Year_y","Runtime_y","Rating_y","Votes_y"], axis=1)
result2.columns
# Out:
# Index(['Name', 'Year_x', 'Rating_x', 'Votes_x', 'Genre1', 'Runtime_x', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre3', 'Description2', 'Director', 'Actors', 'Gross',
#        'Metascore'],
#       dtype='object')

# %%
result2.rename(columns = {'Year_x':'Year', 'Rating_x':'Rating',
                              'Votes_x':'Votes','Runtime_x':'Runtime'}, inplace = True)
result2.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre3', 'Description2', 'Director', 'Actors', 'Gross',
#        'Metascore'],
#       dtype='object')

# %% [markdown]
# #### 4. import the dataset imdb (1000 movies) in june 2022.csv

# %%
df4= pd.read_csv("imdb (1000 movies) in june 2022.csv")
df4.head()
# Out:
#   ranking of movie\r\n                                 movie name\r\n   Year  \
# 0                    1                       The Shawshank Redemption  -1994
# 1                    2                                  The Godfather  -1972
# 2                    3                                The Dark Knight  -2008
# 3                    4  The Lord of the Rings: The Return of the King  -2003
# 4                    5                               Schindler's List  -1993
#
#   certificate  runtime                      genre  RATING  metascore  \
# 0          15  142 min                      Drama     9.3       81.0
# 1           X  175 min               Crime, Drama     9.2      100.0
# 2         12A  152 min       Action, Crime, Drama     9.0       84.0
# 3         12A  201 min   Action, Adventure, Drama     9.0       94.0
# 4          15  195 min  Biography, Drama, History     9.0       94.0
#
#                                 DETAIL ABOUT MOVIE\n          DIRECTOR\r\n  \
# ...

# %%
del df4["ranking of movie\r\n"]

# %%
df4.columns
# Out:
# Index(['movie name\r\n', 'Year', 'certificate', 'runtime', 'genre', 'RATING',
#        'metascore', 'DETAIL ABOUT MOVIE\n', 'DIRECTOR\r\n', 'ACTOR 1\n',
#        'ACTOR 2\n', 'ACTOR 3', 'ACTOR 4', 'votes', 'GROSS COLLECTION\r\n'],
#       dtype='object')

# %% [markdown]
# ##### 4.1.Rename the columns

# %%
df4.rename(columns = {'movie name\r\n':'Name', 'DETAIL ABOUT MOVIE\n':'Description3',
                      'certificate':'Certificate4','RATING':'Rating',
                      'genre':'Genre4','runtime':'Runtime',
                      'metascore':'Metascore',
                      'DIRECTOR\r\n':'Director','ACTOR 1\n':'Actor1',
                      'ACTOR 2\n':'Actor2','ACTOR 3':'Actor3', 'ACTOR 4':'Actor4',
           'votes':'Votes', 'GROSS COLLECTION\r\n':'Gross'}, inplace = True)

# %%
df4
# Out:
#                                               Name   Year Certificate4  \
# 0                         The Shawshank Redemption  -1994           15
# 1                                    The Godfather  -1972            X
# 2                                  The Dark Knight  -2008          12A
# 3    The Lord of the Rings: The Return of the King  -2003          12A
# 4                                 Schindler's List  -1993           15
# ..                                             ...    ...          ...
# 995                                        Sabrina  -1954            U
# 996                          From Here to Eternity  -1953           PG
# 997                Snow White and the Seven Dwarfs  -1937            A
# 998                                   The 39 Steps  -1935            A
# 999                              The Invisible Man  -1933            A
#
#      Runtime                        Genre4  Rating  Metascore  \
# ...

# %% [markdown]
# ##### 4.2.create the third merged dataset ( result 3 )

# %%
result3 = pd.merge(df1,
                 df4,
                 on='Name')
print(result3)
# Out:
#                     Name  Year_x Rating_x  Votes_x  \
# 0                   Dune    2021      8.3   84,636
# 1                   Dune    1984      6.4  142,157
# 2          Casino Royale    2006        8  613,873
# 3          Casino Royale    1967      5.1   28,917
# 4                Skyfall    2012      7.8  658,977
# ..                   ...     ...      ...      ...
# 640  Anatomy of a Murder    1959        8   63,564
# 641                Mommy    2014      8.1   54,020
# 642                Mommy    2014      8.1   54,020
# 643     Double Indemnity    1944      8.3  150,448
# 644     Double Indemnity    1944      8.3  150,448
#
#                           Genre1 Runtime_x  Type Certificate Episodes Nudity  \
# 0       Action, Adventure, Drama       155  Film       PG-13        -   None
# 1      Action, Adventure, Sci-Fi       137  Film       PG-13        -   Mild
# 2    Action, Adventure, Thriller       144  Film       PG-13        -   Mild
# ...

# %%
result3.columns
# Out:
# Index(['Name', 'Year_x', 'Rating_x', 'Votes_x', 'Genre1', 'Runtime_x', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Year_y', 'Certificate4', 'Runtime_y', 'Genre4',
#        'Rating_y', 'Metascore', 'Description3', 'Director', 'Actor1', 'Actor2',
#        'Actor3', 'Actor4', 'Votes_y', 'Gross'],
#       dtype='object')

# %%
result3 = result3.drop(["Year_y","Runtime_y","Rating_y","Votes_y"], axis=1)
result3.columns
# Out:
# Index(['Name', 'Year_x', 'Rating_x', 'Votes_x', 'Genre1', 'Runtime_x', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Certificate4', 'Genre4', 'Metascore', 'Description3',
#        'Director', 'Actor1', 'Actor2', 'Actor3', 'Actor4', 'Gross'],
#       dtype='object')

# %%
result3.rename(columns = {'Year_x':'Year', 'Rating_x':'Rating',
                              'Votes_x':'Votes','Runtime_x':'Runtime'}, inplace = True)
result3.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Certificate4', 'Genre4', 'Metascore', 'Description3',
#        'Director', 'Actor1', 'Actor2', 'Actor3', 'Actor4', 'Gross'],
#       dtype='object')

# %% [markdown]
# #### 5.import the dataset TMDb_updated.csv

# %%
df5= pd.read_csv("TMDb_updated.csv")
df5.head()
# Out:
#    Unnamed: 0                           title  \
# 0           0                        Ad Astra
# 1           1                       Bloodshot
# 2           2               Bad Boys for Life
# 3           3                         Ant-Man
# 4           4  Percy Jackson: Sea of Monsters
#
#                                             overview original_language  \
# 0  The near future, a time when both hope and har...                en
# 1  After he and his wife are murdered, marine Ray...                en
# 2  Marcus and Mike are forced to confront new thr...                en
# 3  Armed with the astonishing ability to shrink i...                en
# 4  In their quest to confront the ultimate evil, ...                en
#
#    vote_count  vote_average
# 0        2853           5.9
# 1        1349           7.2
# 2        2530           7.1
# 3       13611           7.1
# 4        3542           5.9

# %%
del df5["Unnamed: 0"]

# %% [markdown]
# ##### 5.1.Rename the columns

# %%
df5.columns
# Out:
# Index(['title', 'overview', 'original_language', 'vote_count', 'vote_average'], dtype='object')

# %%
df5.rename(columns = {'title':'Name','overview':'Description4',
                      'original_language':'Language',
                      'vote_count':'Votes', 'vote_average':'Average_Votes'}, inplace = True)

# %%
df5
# Out:
#                                 Name  \
# 0                           Ad Astra
# 1                          Bloodshot
# 2                  Bad Boys for Life
# 3                            Ant-Man
# 4     Percy Jackson: Sea of Monsters
# ...                              ...
# 9995                           Cargo
# 9996                  The Good Night
# 9997              The World Is Yours
# 9998             The Grand Seduction
# 9999        Woochi: The Demon Slayer
#
#                                            Description4 Language  Votes  \
# 0     The near future, a time when both hope and har...       en   2853
# 1     After he and his wife are murdered, marine Ray...       en   1349
# 2     Marcus and Mike are forced to confront new thr...       en   2530
# 3     Armed with the astonishing ability to shrink i...       en  13611
# 4     In their quest to confront the ultimate evil, ...       en   3542
# ...                                                 ...      ...    ...
# ...

# %% [markdown]
# ##### 5.2.create the fourth dataset ( result 4 )

# %%
result4 = pd.merge(df1,
                 df5,
                 on='Name')
print(result4)
# Out:
#                                     Name  Year Rating  Votes_x  \
# 0                         No Time to Die  2021    7.6  107,163
# 1                             The Guilty  2021    6.3   64,375
# 2                             The Guilty  2000    6.1    3,446
# 3                                   Dune  2021    8.3   84,636
# 4                                   Dune  2021    8.3   84,636
# ...                                  ...   ...    ...      ...
# 3846                    Double Indemnity  1944    8.3  150,448
# 3847  Before the Devil Knows You're Dead  2007    7.3  100,668
# 3848  Before the Devil Knows You're Dead  2007    7.3  100,668
# 3849                          Death Race  2008    6.3  203,578
# 3850                          Death Race  2008    6.3  203,578
#
#                            Genre1 Runtime  Type Certificate Episodes  \
# 0     Action, Adventure, Thriller     163  Film       PG-13        -
# ...

# %%
result4.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes_x', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Description4', 'Language', 'Votes_y', 'Average_Votes'],
#       dtype='object')

# %%
result4 = result4.drop("Votes_y", axis=1)
result4.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes_x', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Description4', 'Language', 'Average_Votes'],
#       dtype='object')

# %%
result4.rename(columns = {'Votes_x':'Votes'}, inplace = True)
result4.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Description4', 'Language', 'Average_Votes'],
#       dtype='object')

# %% [markdown]
# #### 6. import the dataset NetflixOriginals.csv

# %%
df6= pd.read_csv("NetflixOriginals.csv", encoding = "ISO-8859-1")
df6.head()
# Out:
#              Title                  Genre           Premiere  Runtime  \
# 0  Enter the Anime            Documentary     August 5, 2019       58
# 1      Dark Forces               Thriller    August 21, 2020       81
# 2          The App  Science fiction/Drama  December 26, 2019       79
# 3   The Open House        Horror thriller   January 19, 2018       94
# 4      Kaali Khuhi                Mystery   October 30, 2020       90
#
#    IMDB Score          Language
# 0         2.5  English/Japanese
# 1         2.6           Spanish
# 2         2.6           Italian
# 3         3.2           English
# 4         3.4             Hindi

# %% [markdown]
# ##### 6.1.Rename the columns

# %%
df6.columns
# Out:
# Index(['Title', 'Genre', 'Premiere', 'Runtime', 'IMDB Score', 'Language'], dtype='object')

# %%
df6.rename(columns = {'Title':'Name','IMDB Score':'Rating',
                     'Genre':'Genre5'}, inplace = True)

# %%
df6
# Out:
#                                             Name                 Genre5  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  Rating                  Language
# ...

# %% [markdown]
# ##### 6.2.Create the fifth merged dataset( result5 )

# %%
result5 = pd.merge(df1,
                 df6,
                 on='Name')
print(result5)
# Out:
#                           Name  Year Rating_x    Votes  \
# 0              Hubie Halloween  2020      5.2   44,058
# 1                Gerald's Game  2017      6.5   99,011
# 2             Army of the Dead  2021      5.8  141,683
# 3                     The King  2019      7.2  102,513
# 4       The Devil All the Time  2020      7.1  113,731
# ..                         ...   ...      ...      ...
# 110                   Bad Trip  2021      6.6   21,273
# 111   Ma Rainey's Black Bottom  2020      6.9   47,046
# 112   Ma Rainey's Black Bottom  2020      6.9   47,046
# 113  The Red Sea Diving Resort  2019      6.6   26,953
# 114  The Red Sea Diving Resort  2019      6.6   26,953
#
#                         Genre1 Runtime_x  Type Certificate Episodes    Nudity  \
# 0              Comedy, Mystery       103  Film       PG-13        -      Mild
# 1      Drama, Horror, Thriller       103  Film       TV-MA        -  Moderate
# ...

# %%
result5.columns
# Out:
# Index(['Name', 'Year', 'Rating_x', 'Votes', 'Genre1', 'Runtime_x', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre5', 'Premiere', 'Runtime_y', 'Rating_y',
#        'Language'],
#       dtype='object')

# %%
result5 = result5.drop(["Runtime_y","Rating_y"], axis=1)
result5.columns
# Out:
# Index(['Name', 'Year', 'Rating_x', 'Votes', 'Genre1', 'Runtime_x', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre5', 'Premiere', 'Language'],
#       dtype='object')

# %%
result5.rename(columns = {'Runtime_x':'Runtime', 'Rating_x':'Rating'}, inplace = True)
result5.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre5', 'Premiere', 'Language'],
#       dtype='object')

# %% [markdown]
# #### 7. import the dataset imdb_top_1000.csv

# %%
df7= pd.read_csv("imdb_top_1000.csv")
df7.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %% [markdown]
# ##### 7.1.Rename the columns

# %%
df7.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
df7.rename(columns = {'Series_Title':'Name','IMDB_Rating':'Rating',
                      'Released_Year':'Year','Certificate':'Certificate7',
                      'Overview':'Description5','Meta_score':'Metascore',
                      'No_of_Votes':'Votes',
                     'Genre':'Genre6'}, inplace = True)

# %%
df7
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                          Name  Year Certificate7  Runtime  \
# 0    The Shawshank Redemption  1994            A  142 min
# 1               The Godfather  1972            A  175 min
# 2             The Dark Knight  2008           UA  152 min
# 3      The Godfather: Part II  1974            A  202 min
# ...

# %% [markdown]
# ##### 7.2.create the last merged dataser ( result 6 )

# %%
result6 = pd.merge(df1,
                 df7,
                 on='Name')
print(result6)
# Out:
#                           Name  Year_x Rating_x  Votes_x  \
# 0                Casino Royale    2006        8  613,873
# 1                Casino Royale    1967      5.1   28,917
# 2                      Skyfall    2012      7.8  658,977
# 3    What We Do in the Shadows    2021      8.5   50,078
# 4    What We Do in the Shadows    2014      7.7  169,214
# ..                         ...     ...      ...      ...
# 723                      Mommy    2014      8.1   54,020
# 724                 Chugyeokja    2008      7.8   62,423
# 725                 Chugyeokja    2008      7.8   62,423
# 726           Double Indemnity    1944      8.3  150,448
# 727           Double Indemnity    1944      8.3  150,448
#
#                           Genre1 Runtime_x    Type Certificate Episodes  \
# 0    Action, Adventure, Thriller       144    Film       PG-13        -
# 1                         Comedy       131    Film    Approved        -
# ...

# %%
result6.columns
# Out:
# Index(['Name', 'Year_x', 'Rating_x', 'Votes_x', 'Genre1', 'Runtime_x', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Poster_Link', 'Year_y', 'Certificate7', 'Runtime_y',
#        'Genre6', 'Rating_y', 'Description5', 'Metascore', 'Director', 'Star1',
#        'Star2', 'Star3', 'Star4', 'Votes_y', 'Gross'],
#       dtype='object')

# %%
result6 = result6.drop(["Year_y","Runtime_y","Runtime_y","Votes_y"], axis=1)
result6.columns
# Out:
# Index(['Name', 'Year_x', 'Rating_x', 'Votes_x', 'Genre1', 'Runtime_x', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Poster_Link', 'Certificate7', 'Genre6', 'Rating_y',
#        'Description5', 'Metascore', 'Director', 'Star1', 'Star2', 'Star3',
#        'Star4', 'Gross'],
#       dtype='object')

# %%
result6.rename(columns = {'Runtime_x':'Runtime', 'Rating_x':'Rating',
                         'Year_x':'Year', 'Votes_x':'Votes'}, inplace = True)
result6.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Poster_Link', 'Certificate7', 'Genre6', 'Rating_y',
#        'Description5', 'Metascore', 'Director', 'Star1', 'Star2', 'Star3',
#        'Star4', 'Gross'],
#       dtype='object')

# %% [markdown]
# #### 8. gather the 7 mergerd datasets with union

# %%
dfs = [result1, result2, result3, result4, result5 ,result6]

# %%
#union = pd.concat(dfs,
 #                verify_integrity=True
  #               )

# %%
union = pd.concat(dfs)
print(union)
# Out:
#                           Name  Year Rating    Votes  \
# 0                Casino Royale  2006      8  613,873
# 1                Casino Royale  1967    5.1   28,917
# 2                      Skyfall  2012    7.8  658,977
# 3    What We Do in the Shadows  2021    8.5   50,078
# 4    What We Do in the Shadows  2014    7.7  169,214
# ..                         ...   ...    ...      ...
# 723                      Mommy  2014    8.1   54,020
# 724                 Chugyeokja  2008    7.8   62,423
# 725                 Chugyeokja  2008    7.8   62,423
# 726           Double Indemnity  1944    8.3  150,448
# 727           Double Indemnity  1944    8.3  150,448
#
#                           Genre1 Runtime    Type Certificate Episodes  \
# 0    Action, Adventure, Thriller     144    Film       PG-13        -
# 1                         Comedy     131    Film    Approved        -
# 2    Action, Adventure, Thriller     143    Film       PG-13        -
# ...

# %%
union.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre2', 'Metascore', 'Description1', 'Gross', 'Genre3',
#        'Description2', 'Director', 'Actors', 'Certificate4', 'Genre4',
#        'Description3', 'Actor1', 'Actor2', 'Actor3', 'Actor4', 'Description4',
#        'Language', 'Average_Votes', 'Genre5', 'Premiere', 'Poster_Link',
#        'Certificate7', 'Genre6', 'Rating_y', 'Description5', 'Star1', 'Star2',
#        'Star3', 'Star4'],
#       dtype='object')

# %%
union.to_csv('final2.csv')

# %% [markdown]
# #### removing the duplicates from the dataset

# %%
without_dub_union = union.drop_duplicates()
print(without_dub_union)
# Out:
#                           Name  Year Rating    Votes  \
# 0                Casino Royale  2006      8  613,873
# 1                Casino Royale  1967    5.1   28,917
# 2                      Skyfall  2012    7.8  658,977
# 3    What We Do in the Shadows  2021    8.5   50,078
# 4    What We Do in the Shadows  2014    7.7  169,214
# ..                         ...   ...    ...      ...
# 718        Lucky Number Slevin  2006    7.7  306,275
# 720        Anatomy of a Murder  1959      8   63,564
# 722                      Mommy  2014    8.1   54,020
# 724                 Chugyeokja  2008    7.8   62,423
# 726           Double Indemnity  1944    8.3  150,448
#
#                           Genre1 Runtime    Type Certificate Episodes  \
# 0    Action, Adventure, Thriller     144    Film       PG-13        -
# 1                         Comedy     131    Film    Approved        -
# 2    Action, Adventure, Thriller     143    Film       PG-13        -
# ...

# %%
without_dub_union.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre2', 'Metascore', 'Description1', 'Gross', 'Genre3',
#        'Description2', 'Director', 'Actors', 'Certificate4', 'Genre4',
#        'Description3', 'Actor1', 'Actor2', 'Actor3', 'Actor4', 'Description4',
#        'Language', 'Average_Votes', 'Genre5', 'Premiere', 'Poster_Link',
#        'Certificate7', 'Genre6', 'Rating_y', 'Description5', 'Star1', 'Star2',
#        'Star3', 'Star4'],
#       dtype='object')

# %%
del without_dub_union["Rating_y"]

# %%
without_dub_union.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre2', 'Metascore', 'Description1', 'Gross', 'Genre3',
#        'Description2', 'Director', 'Actors', 'Certificate4', 'Genre4',
#        'Description3', 'Actor1', 'Actor2', 'Actor3', 'Actor4', 'Description4',
#        'Language', 'Average_Votes', 'Genre5', 'Premiere', 'Poster_Link',
#        'Certificate7', 'Genre6', 'Description5', 'Star1', 'Star2', 'Star3',
#        'Star4'],
#       dtype='object')

# %%
without_dub_union.to_csv('without_dub_union.csv')

# %% [markdown]
# #### 9 Union of genre

# %%
without_dub_union.columns
# Out:
# Index(['Name', 'Year', 'Rating', 'Votes', 'Genre1', 'Runtime', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening', 'Genre2', 'Metascore', 'Description1', 'Gross', 'Genre3',
#        'Description2', 'Director', 'Actors', 'Certificate4', 'Genre4',
#        'Description3', 'Actor1', 'Actor2', 'Actor3', 'Actor4', 'Description4',
#        'Language', 'Average_Votes', 'Genre5', 'Premiere', 'Poster_Link',
#        'Certificate7', 'Genre6', 'Description5', 'Star1', 'Star2', 'Star3',
#        'Star4'],
#       dtype='object')

# %% [markdown]
# #### Genre1

# %%
genre_1 = without_dub_union[['Genre1']].copy()

# %%
genre_1[['G1', 'G2', 'G3']] = genre_1['Genre1'].str.split(',', expand=True)
genre1_1= genre_1.drop(['Genre1'], axis=1)
genre1_1
# Out:
#          G1          G2          G3
# 0    Action   Adventure    Thriller
# 1    Comedy        None        None
# 2    Action   Adventure    Thriller
# 3    Comedy     Fantasy      Horror
# 4    Comedy      Horror        None
# ..      ...         ...         ...
# 718   Crime       Drama    Thriller
# 720   Drama     Mystery        None
# 722   Drama        None        None
# 724  Action       Crime    Thriller
# 726   Crime       Drama   Film-Noir
#
# [5803 rows x 3 columns]

# %% [markdown]
# #### Genre 2

# %%
genre_2 = without_dub_union[['Genre2']].copy()
genre_2[['G4', 'G5', 'G6']] = genre_2['Genre2'].str.split(',', expand=True)
genre2_1= genre_2.drop(['Genre2'], axis=1)
genre2_1
# Out:
#          G4          G5         G6
# 0    Action   Adventure   Thriller
# 1    Action   Adventure   Thriller
# 2    Action   Adventure   Thriller
# 3    Comedy      Horror       None
# 4    Comedy      Horror       None
# ..      ...         ...        ...
# 718     NaN         NaN        NaN
# 720     NaN         NaN        NaN
# 722     NaN         NaN        NaN
# 724     NaN         NaN        NaN
# 726     NaN         NaN        NaN
#
# [5803 rows x 3 columns]

# %% [markdown]
# #### Genre3

# %%
genre_3 = without_dub_union[['Genre3']].copy()
genre_3[['G7', 'G8', 'G9']] = genre_3['Genre3'].str.split(',', expand=True)
genre3_1= genre_3.drop(['Genre3'], axis=1)
genre3_1
# Out:
#       G7   G8   G9
# 0    NaN  NaN  NaN
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# ..   ...  ...  ...
# 718  NaN  NaN  NaN
# 720  NaN  NaN  NaN
# 722  NaN  NaN  NaN
# 724  NaN  NaN  NaN
# 726  NaN  NaN  NaN
#
# [5803 rows x 3 columns]

# %% [markdown]
# #### Genre4

# %%
genre_4 = without_dub_union[['Genre4']].copy()
genre_4[['G10', 'G11', 'G12']] = genre_4['Genre4'].str.split(',', expand=True)
genre4_1= genre_4.drop(['Genre4'], axis=1)
genre4_1
# Out:
#      G10  G11  G12
# 0    NaN  NaN  NaN
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# ..   ...  ...  ...
# 718  NaN  NaN  NaN
# 720  NaN  NaN  NaN
# 722  NaN  NaN  NaN
# 724  NaN  NaN  NaN
# 726  NaN  NaN  NaN
#
# [5803 rows x 3 columns]

# %% [markdown]
# #### Genre6

# %%
genre_6 = without_dub_union[['Genre6']].copy()
genre_6[['G13', 'G14','G15']] = genre_6['Genre6'].str.split(',', expand=True)
genre6_1= genre_6.drop(['Genre6'], axis=1)
genre6_1
# Out:
#         G13     G14         G15
# 0       NaN     NaN         NaN
# 1       NaN     NaN         NaN
# 2       NaN     NaN         NaN
# 3       NaN     NaN         NaN
# 4       NaN     NaN         NaN
# ..      ...     ...         ...
# 718  Action   Crime       Drama
# 720   Crime   Drama     Mystery
# 722   Drama    None        None
# 724  Action   Crime    Thriller
# 726   Crime   Drama   Film-Noir
#
# [5803 rows x 3 columns]

# %%
genre1_1.dtypes
# Out:
# G1    object
# G2    object
# G3    object
# dtype: object

# %%
genre1_1.G1.unique()
# Out:
# array(['Action', 'Comedy', 'Horror', 'Crime', 'Drama', 'Biography',
#        'Adventure', 'Animation', 'Mystery', 'Family', 'Western',
#        'Fantasy', 'Sci-Fi', 'Thriller', 'Romance', 'Musical', 'Game-Show',
#        'Short'], dtype=object)

# %%
#genre1_1['G1'].astype(str)

#genre1_1['G1'] = genre1_1['G1'].astype('|S80') 

#genre1_1['G1'] = genre1_1['G1'].astype('str')

# %% [markdown]
# #### Changes

# %%
genre1_1.G1
# Out:
# 0      Action
# 1      Comedy
# 2      Action
# 3      Comedy
# 4      Comedy
#         ...
# 718     Crime
# 720     Drama
# 722     Drama
# 724    Action
# 726     Crime
# Name: G1, Length: 5803, dtype: object

# %%
genre1_1.G2.unique()
# Out:
# array(['Adventure', None, 'Fantasy', 'Horror', 'Thriller', 'Crime',
#        'Romance', 'Drama', 'Sci-Fi', 'Comedy', 'Family', 'Western',
#        'Mystery', 'War', 'Action', 'Music', 'Biography', 'History',
#        'Sport', 'Film-Noir', 'Musical', 'Game-Show', 'Reality-TV'],
#       dtype=object)

# %%
genre1_1.G2 = genre1_1['G2'].str.replace(' ', '')

# %%
genre1_1.G3.unique()
# Out:
# array(['Thriller', None, 'Horror', 'Drama', 'Mystery', 'Crime', 'Fantasy',
#        'Sci-Fi', 'War', 'Family', 'Romance', 'Comedy', 'Music', 'History',
#        'Adventure', 'Sport', 'Western', 'Musical', 'Film-Noir',
#        'Biography', 'Reality-TV'], dtype=object)

# %%
genre1_1.G3 = genre1_1['G3'].str.replace(' ', '')

# %%
genre1_1
# Out:
#          G1          G2         G3
# 0    Action   Adventure   Thriller
# 1    Comedy        None       None
# 2    Action   Adventure   Thriller
# 3    Comedy     Fantasy     Horror
# 4    Comedy      Horror       None
# ..      ...         ...        ...
# 718   Crime       Drama   Thriller
# 720   Drama     Mystery       None
# 722   Drama        None       None
# 724  Action       Crime   Thriller
# 726   Crime       Drama  Film-Noir
#
# [5803 rows x 3 columns]

# %%
genre2_1.G4.unique()
# Out:
# array(['Action', 'Comedy', 'Horror', 'Drama', 'Crime', 'Biography',
#        'Adventure', 'Animation', 'Mystery', 'Family', 'Western',
#        'Fantasy', nan], dtype=object)

# %%
genre2_1.G5.unique()
# Out:
# array(['Adventure', 'Horror', 'Thriller', 'Crime', 'Romance', 'Drama',
#        'Sci-Fi', None, 'Family', 'Comedy', 'Western', 'Mystery',
#        'Fantasy', 'War', 'Action', 'Music', 'Biography', 'History',
#        'Sport', 'Film-Noir', 'Musical', nan], dtype=object)

# %%
genre2_1.G5 = genre2_1['G5'].str.replace(' ', '')

# %%
genre2_1.G6.unique()
# Out:
# array(['Thriller', None, 'Drama', 'Mystery', 'Fantasy', 'Sci-Fi', 'War',
#        'Family', 'Comedy', 'Music', 'Film-Noir', 'Crime', 'History',
#        'Romance', 'Adventure', 'Sport', 'Western', 'Musical', 'Horror',
#        nan], dtype=object)

# %%
genre2_1.G6 = genre2_1['G6'].str.replace(' ', '')

# %%
genre3_1.columns
# Out:
# Index(['G7', 'G8', 'G9'], dtype='object')

# %%
genre3_1.G7.unique()
# Out:
# array([nan, 'Action', 'Comedy', 'Drama', 'Biography', 'Crime',
#        'Adventure', 'Horror', 'Mystery', 'Animation', 'Thriller',
#        'Fantasy', 'Romance', 'Sci-Fi'], dtype=object)

# %%
genre3_1.G8.unique()
# Out:
# array([nan, 'Adventure', 'Fantasy', 'Family', 'Comedy', 'Drama', 'Horror',
#        'Crime', 'Sci-Fi', 'Western', None, 'Thriller', 'Mystery',
#        'Romance', 'Music', 'History', 'War', 'Biography', 'Musical',
#        'Sport', 'Action'], dtype=object)

# %%
genre3_1.G9.unique()
# Out:
# array([nan, 'Thriller', 'Horror', 'Fantasy', 'Crime', 'History', 'Sci-Fi',
#        'Drama', None, 'Mystery', 'Romance', 'War', 'Comedy', 'Family',
#        'Sport', 'Music', 'Western', 'Musical', 'Biography', 'Adventure'],
#       dtype=object)

# %%
genre4_1.columns
# Out:
# Index(['G10', 'G11', 'G12'], dtype='object')

# %%
genre4_1.G10.unique()
# Out:
# array([nan, 'Action', 'Comedy', 'Horror', 'Drama', 'Biography', 'Crime',
#        'Animation', 'Adventure', 'Mystery', 'Family', 'Western',
#        'Fantasy'], dtype=object)

# %%
genre4_1.G11.unique()
# Out:
# array([nan, 'Adventure', 'Horror', 'Thriller', 'Crime', 'Romance',
#        'Drama', 'Sci-Fi', 'Comedy', None, 'Family', 'Mystery', 'Western',
#        'Fantasy', 'War', 'Biography', 'Action', 'Music', 'Sport',
#        'History', 'Film-Noir', 'Musical'], dtype=object)

# %%
genre4_1.G11 = genre4_1['G11'].str.replace(' ', '')

# %%
genre4_1.G12.unique()
# Out:
# array([nan, 'Drama', 'Thriller', None, 'Fantasy', 'Mystery', 'Crime',
#        'Sci-Fi', 'War', 'Music', 'Family', 'Comedy', 'Horror',
#        'Film-Noir', 'History', 'Romance', 'Adventure', 'Sport', 'Western',
#        'Musical'], dtype=object)

# %%
genre4_1.G12 = genre4_1['G12'].str.replace(' ', '')

# %%
genre6_1.columns
# Out:
# Index(['G13', 'G14', 'G15'], dtype='object')

# %%
genre6_1.G13.unique()
# Out:
# array([nan, 'Action', 'Comedy', 'Horror', 'Drama', 'Crime', 'Biography',
#        'Adventure', 'Animation', 'Mystery', 'Western', 'Family',
#        'Fantasy', 'Film-Noir'], dtype=object)

# %%
genre6_1.G14.unique()
# Out:
# array([nan, ' Adventure', ' Horror', ' Thriller', ' Crime', ' Drama',
#        ' Romance', ' Sci-Fi', None, ' Family', ' Comedy', ' Western',
#        ' Mystery', ' Fantasy', ' War', ' Action', ' Music', ' History',
#        ' Biography', ' Sport', ' Film-Noir', ' Musical'], dtype=object)

# %%
genre6_1.G14 = genre6_1['G14'].str.replace(' ', '')

# %%
genre6_1.G15.unique()
# Out:
# array([nan, 'Thriller', None, 'Drama', 'Mystery', 'Fantasy', 'Sci-Fi',
#        'War', 'Family', 'Comedy', 'Music', 'Film-Noir', 'Crime',
#        'History', 'Horror', 'Romance', 'Adventure', 'Sport', 'Western',
#        'Musical'], dtype=object)

# %%
genre6_1.G15 = genre6_1['G15'].str.replace(' ', '')

# %%
df["G"] = df['Courses'].astype(str) +"-"+ df["Duration"]
print(df)

# %%
union_genres = genre1_1.union(genre2_1, genre3_1,genre4_1, genre6_1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [182], line 1
# ----> 1 union_genres = genre1_1.union(genre2_1, genre3_1,genre4_1, genre6_1)
#
# File ~\Desktop\MASTER\SEMESTER 3\DIPLOMATIKI\course_venv\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'union'

# %%
genre_columns

# %%
 genre_columns=without_dub_union.drop(['Genre1', 'Genre2','Genre3', 'Genre4','Genre5', 'Genre6'], axis=1)

# %%
dfs2 = [genre1_1, genre2_1, genre3_1, genre4_1, genre6_1]
genres_union = pd.concat(dfs2)
print(genres_union)
# Out:
#          G1          G2         G3   G4   G5   G6   G7   G8   G9  G10  G11  \
# 0    Action   Adventure   Thriller  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    Comedy        None       None  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    Action   Adventure   Thriller  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    Comedy     Fantasy     Horror  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4    Comedy      Horror       None  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..      ...         ...        ...  ...  ...  ...  ...  ...  ...  ...  ...
# 718     NaN         NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 720     NaN         NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 722     NaN         NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 724     NaN         NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 726     NaN         NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#      G12     G13     G14         G15
# ...

# %%
genres_union.to_csv('genres_union.csv')

# %%
genre1_1["gg1"] = genre1_1['G1'].astype(str) +","+ genre1_1["G2"] +","+ genre1_1["G3"]
print(genre1_1)
# Out:
#          G1         G2         G3                        gg1
# 0    Action  Adventure   Thriller  Action,Adventure,Thriller
# 1    Comedy       None       None                        NaN
# 2    Action  Adventure   Thriller  Action,Adventure,Thriller
# 3    Comedy    Fantasy     Horror      Comedy,Fantasy,Horror
# 4    Comedy     Horror       None                        NaN
# ..      ...        ...        ...                        ...
# 718   Crime      Drama   Thriller       Crime,Drama,Thriller
# 720   Drama    Mystery       None                        NaN
# 722   Drama       None       None                        NaN
# 724  Action      Crime   Thriller      Action,Crime,Thriller
# 726   Crime      Drama  Film-Noir      Crime,Drama,Film-Noir
#
# [5803 rows x 4 columns]

# %%
genre2_1["gg2"] = genre2_1['G4'].astype(str) +","+ genre2_1["G5"] +","+ genre2_1["G6"]
print(genre2_1)
# Out:
#          G4         G5        G6                        gg2
# 0    Action  Adventure  Thriller  Action,Adventure,Thriller
# 1    Action  Adventure  Thriller  Action,Adventure,Thriller
# 2    Action  Adventure  Thriller  Action,Adventure,Thriller
# 3    Comedy     Horror      None                        NaN
# 4    Comedy     Horror      None                        NaN
# ..      ...        ...       ...                        ...
# 718     NaN        NaN       NaN                        NaN
# 720     NaN        NaN       NaN                        NaN
# 722     NaN        NaN       NaN                        NaN
# 724     NaN        NaN       NaN                        NaN
# 726     NaN        NaN       NaN                        NaN
#
# [5803 rows x 4 columns]

# %%
genre3_1["gg3"] = genre3_1['G7'].astype(str) +","+ genre3_1["G8"] +","+ genre3_1["G8"]
print(genre3_1)
# Out:
#       G7   G8   G9  gg2  gg3
# 0    NaN  NaN  NaN  NaN  NaN
# 1    NaN  NaN  NaN  NaN  NaN
# 2    NaN  NaN  NaN  NaN  NaN
# 3    NaN  NaN  NaN  NaN  NaN
# 4    NaN  NaN  NaN  NaN  NaN
# ..   ...  ...  ...  ...  ...
# 718  NaN  NaN  NaN  NaN  NaN
# 720  NaN  NaN  NaN  NaN  NaN
# 722  NaN  NaN  NaN  NaN  NaN
# 724  NaN  NaN  NaN  NaN  NaN
# 726  NaN  NaN  NaN  NaN  NaN
#
# [5803 rows x 5 columns]

# %%
genre4_1["gg4"] = genre4_1['G10'].astype(str) +","+ genre4_1["G11"] +","+ genre4_1["G12"]
print(genre4_1)
# Out:
#      G10  G11  G12  gg4
# 0    NaN  NaN  NaN  NaN
# 1    NaN  NaN  NaN  NaN
# 2    NaN  NaN  NaN  NaN
# 3    NaN  NaN  NaN  NaN
# 4    NaN  NaN  NaN  NaN
# ..   ...  ...  ...  ...
# 718  NaN  NaN  NaN  NaN
# 720  NaN  NaN  NaN  NaN
# 722  NaN  NaN  NaN  NaN
# 724  NaN  NaN  NaN  NaN
# 726  NaN  NaN  NaN  NaN
#
# [5803 rows x 4 columns]

# %%
genre6_1["gg6"] = genre6_1['G13'].astype(str) +","+ genre6_1["G14"] +","+ genre6_1["G15"]
print(genre6_1)
# Out:
#         G13    G14        G15                    gg4                    gg6
# 0       NaN    NaN        NaN                    NaN                    NaN
# 1       NaN    NaN        NaN                    NaN                    NaN
# 2       NaN    NaN        NaN                    NaN                    NaN
# 3       NaN    NaN        NaN                    NaN                    NaN
# 4       NaN    NaN        NaN                    NaN                    NaN
# ..      ...    ...        ...                    ...                    ...
# 718  Action  Crime      Drama     Action,Crime,Drama     Action,Crime,Drama
# 720   Crime  Drama    Mystery    Crime,Drama,Mystery    Crime,Drama,Mystery
# 722   Drama   None       None                    NaN                    NaN
# 724  Action  Crime   Thriller  Action,Crime,Thriller  Action,Crime,Thriller
# 726   Crime  Drama  Film-Noir  Crime,Drama,Film-Noir  Crime,Drama,Film-Noir
#
# [5803 rows x 5 columns]

# %%
all_genres = pd.concat([genre1_1.gg1, genre2_1.gg2, genre3_1.gg3, genre4_1.gg4, genre6_1.gg6], axis=1)
all_genres
# Out:
#                            gg1                        gg2  gg3  gg4  \
# 0    Action,Adventure,Thriller  Action,Adventure,Thriller  NaN  NaN
# 1                          NaN  Action,Adventure,Thriller  NaN  NaN
# 2    Action,Adventure,Thriller  Action,Adventure,Thriller  NaN  NaN
# 3        Comedy,Fantasy,Horror                        NaN  NaN  NaN
# 4                          NaN                        NaN  NaN  NaN
# ..                         ...                        ...  ...  ...
# 718       Crime,Drama,Thriller                        NaN  NaN  NaN
# 720                        NaN                        NaN  NaN  NaN
# 722                        NaN                        NaN  NaN  NaN
# 724      Action,Crime,Thriller                        NaN  NaN  NaN
# 726      Crime,Drama,Film-Noir                        NaN  NaN  NaN
#
#                        gg6
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# ...

# %%
all_genres["combination1"] = all_genres['gg1'].astype(str) +","+ all_genres["gg2"] 
all_genres["combination2"] = all_genres['gg3'].astype(str) +","+ all_genres["gg4"] 
all_genres["combination3"] = all_genres['combination1'].astype(str) +","+ all_genres["combination2"] 
all_genres["final_combination"] = all_genres['combination3'].astype(str) +","+ all_genres["gg6"] 
print(all_genres)
# Out:
#                            gg1                        gg2  gg3  gg4  \
# 0    Action,Adventure,Thriller  Action,Adventure,Thriller  NaN  NaN
# 1                          NaN  Action,Adventure,Thriller  NaN  NaN
# 2    Action,Adventure,Thriller  Action,Adventure,Thriller  NaN  NaN
# 3        Comedy,Fantasy,Horror                        NaN  NaN  NaN
# 4                          NaN                        NaN  NaN  NaN
# ..                         ...                        ...  ...  ...
# 718       Crime,Drama,Thriller                        NaN  NaN  NaN
# 720                        NaN                        NaN  NaN  NaN
# 722                        NaN                        NaN  NaN  NaN
# 724      Action,Crime,Thriller                        NaN  NaN  NaN
# 726      Crime,Drama,Film-Noir                        NaN  NaN  NaN
#
#                        gg6                                       combination1  \
# ...

# %%
all_genres["combination3"] = all_genres['combination1'].astype(str) +","+ all_genres["combination2"] 
print(all_genres.combination3)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 718    NaN
# 720    NaN
# 722    NaN
# 724    NaN
# 726    NaN
# Name: combination3, Length: 5803, dtype: object

# %%
all_genres["final_combination"] = all_genres['combination3'].astype(str) +","+ all_genres["gg6"]

# %%
df7.dtypes
# Out:
# Poster_Link      object
# Name             object
# Year             object
# Certificate7     object
# Runtime          object
# Genre6           object
# Rating          float64
# Description5     object
# Metascore       float64
# Director         object
# Star1            object
# Star2            object
# Star3            object
# Star4            object
# Votes             int64
# Gross            object
# dtype: object
